# %% [markdown]
# # AutoLyrics — Colab Training
#
# Run this on Google Colab with a **T4 GPU** (free tier) or better.
# Runtime → Change runtime type → Hardware accelerator: GPU.
#
# ## Workflow
# 1. Upload your local `data/processed/hf_dataset/` folder to Google Drive (or zip + upload).
# 2. Upload the `src/` folder + `configs/` folder to Drive too (or clone from GitHub).
# 3. Run cells below. Adapter is saved back to Drive.
# 4. Download `final_adapter/` to your local machine → drop into `outputs/checkpoints/final_adapter/`.
# 5. Run `python scripts/evaluate.py` and `python app.py` locally.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Set this to where you uploaded the AutoLyrics project on Drive
PROJECT_DIR = '/content/drive/MyDrive/AutoLyrics'  # adjust if different
# %cd {PROJECT_DIR}
# !ls

# %%
# Install dependencies (Colab has torch + cuda preinstalled)
# !pip install -q transformers==4.46.3 accelerate==1.1.1 datasets==3.1.0 \
    peft==0.13.2 bitsandbytes==0.44.1 jiwer==3.0.5 omegaconf==2.3.0 \
    librosa soundfile tensorboard wandb

# %%
# Install the project package (editable)
# !pip install -e .

# %%
# Sanity check GPU
import torch
print('CUDA:', torch.cuda.is_available())
print('Device:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU')

# %%
# Train (uses 8-bit on GPU automatically)
# !python scripts/train.py

# %%
# Evaluate
# !python scripts/evaluate.py

# %%
# Zip the trained adapter for download
# !cd outputs/checkpoints && zip -r final_adapter.zip final_adapter/
from google.colab import files
files.download('outputs/checkpoints/final_adapter.zip')
